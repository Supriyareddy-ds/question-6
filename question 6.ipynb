# %% [markdown]
# Top 10 ODI women's cricket team

# %%
from bs4 import BeautifulSoup
import requests

# %%
page=requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")

# %%
Soup=BeautifulSoup(page.content,'html.parser')

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:image" content="https://w
# ...

# %%
print(Soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
team=[]
matches=[]
points=[]
rating=[]

# %%
team1=Soup.find_all('span',class_="u-hide-phablet")
team1[0:10]
# Out:
# [<span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">Ireland</span>]

# %%
matches1=Soup.find_all('td',class_="rankings-block__banner--matches")
matches1[0:10]
# Out:
# [<td class="rankings-block__banner--matches">15</td>]

# %%
matches2=Soup.find_all('td',class_="table-body__cell u-center-text")
matches2[0:10]
# Out:
# [<td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>,
#  <td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">2,090</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,384</td>,
#  <td class="table-body__cell u-center-text">12</td>,
#  <td class="table-body__cell u-center-text">1,025</td>]

# %%
rating1=Soup.find_all('td',class_="rankings-block__banner--matches")
rating1[0:10]
# Out:
# [<td class="rankings-block__banner--matches">15</td>]

# %%
rating2=Soup.find_all('td',class_="table-body__cell u-center-text")
rating2[0:10]
# Out:
# [<td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>,
#  <td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">2,090</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,384</td>,
#  <td class="table-body__cell u-center-text">12</td>,
#  <td class="table-body__cell u-center-text">1,025</td>]

# %%
rating3=rating1+rating2
rating3
# Out:
# [<td class="rankings-block__banner--matches">15</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>,
#  <td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">2,090</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,384</td>,
#  <td class="table-body__cell u-center-text">12</td>,
#  <td class="table-body__cell u-center-text">1,025</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,101</td>,
#  <td class="table-body__cell u-center-text">5</td>,
#  <td class="table-body__cell u-center-text">306</td>,
#  <td class="table-body__cell u-center-text">11</td>,
#  <td class="table-body__cell u-center-text">519</td>,
# ...

# %%
points1=Soup.find_all('td',class_="rankings-block__banner--matches")
points1[0:10]
# Out:
# [<td class="rankings-block__banner--matches">15</td>]

# %%
points2=Soup.find_all('td',class_="table-body__cell u-center-text")
points2[0:10]
# Out:
# [<td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>,
#  <td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">2,090</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,384</td>,
#  <td class="table-body__cell u-center-text">12</td>,
#  <td class="table-body__cell u-center-text">1,025</td>]

# %%
points3=points1+points2
points3
# Out:
# [<td class="rankings-block__banner--matches">15</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>,
#  <td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">2,090</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,384</td>,
#  <td class="table-body__cell u-center-text">12</td>,
#  <td class="table-body__cell u-center-text">1,025</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,101</td>,
#  <td class="table-body__cell u-center-text">5</td>,
#  <td class="table-body__cell u-center-text">306</td>,
#  <td class="table-body__cell u-center-text">11</td>,
#  <td class="table-body__cell u-center-text">519</td>,
# ...

# %%
for i in team1:
    team.append(i.get_text().replace('\n',''))
team[0:10]
# Out:
# ['Australia',
#  'India',
#  'England',
#  'South Africa',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'Ireland']

# %%
for i in matches1:
    matches.append(i.get_text().replace('\n',''))
matches[0:10]
# Out:
# ['15']

# %%
for i in rating1:
    rating.append(i.get_text().replace('\n',''))
rating[0:10]
# Out:
# ['15']

# %%
for i in points1:
    points.append(i.get_text().replace('\n',''))
points[0:10]
# Out:
# ['15']

# %%
TEAM=[]
MATCHES=[]
POINTS=[]
RATING=[]

# %%
import pandas as pd
womencricket=pd.DataFrame()
womencricket['TEAM']=team[0:4]
womencricket['MATCHES']=matches[0:4]
womencricket['POINTS']=points[0:4]
womencricket['RATING']=rating[0:4]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-66f76cffeaea> in <module>
#       2 womencricket=pd.DataFrame()
#       3 womencricket['TEAM']=team[0:4]
# ----> 4 womencricket['MATCHES']=matches[0:4]
#       5 womencricket['POINTS']=points[0:4]
#       6 womencricket['RATING']=rating[0:4]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ...

# %%
womencricket
# Out:
#            TEAM
# 0     Australia
# 1         India
# 2       England
# 3  South Africa
# 4   New Zealand
# 5   West Indies
# 6      Pakistan
# 7    Bangladesh
# 8     Sri Lanka
# 9       Ireland

# %%
# top 10 ODI batting in womens cricket team

# %%
page1=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting")

# %%
Soup=BeautifulSoup(page1.content,'html.parser')

# %%
page1.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
name1=Soup.find_all('div',class_="rankings-block__banner--name-large")
name1[0:10]
# Out:
# [<div class="rankings-block__banner--name-large">Meg Lanning</div>]

# %%
name2=Soup.find_all('td',class_="table-body__cell rankings-table__name name")
name2[0:10]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/545">Tammy Beaumont</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/3176">Laura Wolvaardt</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/471">Ellyse Perry</a>
#  </td>,
# ...

# %%
name=name1+name2
name
# Out:
# [<div class="rankings-block__banner--name-large">Meg Lanning</div>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/545">Tammy Beaumont</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/3176">Laura Wolvaardt</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
# ...

# %%
for i in name1:
    name.append(i.get_text().replace('\n',''))
name[0:10]
# Out:
# [<div class="rankings-block__banner--name-large">Meg Lanning</div>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/545">Tammy Beaumont</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/3176">Laura Wolvaardt</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
# ...

# %%
team1=Soup.find_all('div',class_="rankings-block__banner--name-large")
team1[0:10]
# Out:
# [<div class="rankings-block__banner--name-large">Meg Lanning</div>]

# %%
team2=Soup.find_all('span',class_="table-body__logo-text")
team2[0:10]
# Out:
# [<span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>]

# %%
team=team1+team2
team
# Out:
# [<div class="rankings-block__banner--name-large">Meg Lanning</div>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SL</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
# ...

# %%
for i in team1:
    team.append(i.get_text().replace('\n',''))
team[0:10]
# Out:
# [<div class="rankings-block__banner--name-large">Meg Lanning</div>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>]

# %%
rate1=Soup.find_all('div',class_="rankings-block__banner--rating")
rate1[0:10]
# Out:
# [<div class="rankings-block__banner--rating">749</div>]

# %%
rate2=Soup.find_all('td',class_="table-body__cell rating")
rate2[0:10]
# Out:
# [<td class="table-body__cell rating">746</td>,
#  <td class="table-body__cell rating">741</td>,
#  <td class="table-body__cell rating">732</td>,
#  <td class="table-body__cell rating">723</td>,
#  <td class="table-body__cell rating">716</td>,
#  <td class="table-body__cell rating">691</td>,
#  <td class="table-body__cell rating">691</td>,
#  <td class="table-body__cell rating">687</td>,
#  <td class="table-body__cell rating">681</td>,
#  <td class="table-body__cell rating">670</td>]

# %%
rate=rate1+rate2
rate
# Out:
# [<div class="rankings-block__banner--rating">749</div>,
#  <td class="table-body__cell rating">746</td>,
#  <td class="table-body__cell rating">741</td>,
#  <td class="table-body__cell rating">732</td>,
#  <td class="table-body__cell rating">723</td>,
#  <td class="table-body__cell rating">716</td>,
#  <td class="table-body__cell rating">691</td>,
#  <td class="table-body__cell rating">691</td>,
#  <td class="table-body__cell rating">687</td>,
#  <td class="table-body__cell rating">681</td>,
#  <td class="table-body__cell rating">670</td>,
#  <td class="table-body__cell rating">667</td>,
#  <td class="table-body__cell rating">655</td>,
#  <td class="table-body__cell rating">651</td>,
#  <td class="table-body__cell rating">649</td>,
#  <td class="table-body__cell rating">641</td>,
#  <td class="table-body__cell rating">603</td>,
#  <td class="table-body__cell rating">594</td>,
#  <td class="table-body__cell rating">569</td>,
#  <td class="table-body__cell rating">562</td>,
# ...

# %%
for i in rate1:
    rate.append(i.get_text().replace('\n',''))
rate[0:10]
# Out:
# [<div class="rankings-block__banner--rating">749</div>,
#  <td class="table-body__cell rating">746</td>,
#  <td class="table-body__cell rating">741</td>,
#  <td class="table-body__cell rating">732</td>,
#  <td class="table-body__cell rating">723</td>,
#  <td class="table-body__cell rating">716</td>,
#  <td class="table-body__cell rating">691</td>,
#  <td class="table-body__cell rating">691</td>,
#  <td class="table-body__cell rating">687</td>,
#  <td class="table-body__cell rating">681</td>]

# %%
NAME=[]
TEAM=[]
RATING=[]

# %%
import pandas as pd
top10_batswoman=pd.DataFrame()
top10_batswoman['NAME']=name[0:10]
top10_batswoman['TEAM']=team[0:10]
top10_batswoman['RATING']=rating[0:10]

# %%
top10_batswoman
# Out:
#                             NAME           TEAM   RATING
# 0                  [Meg Lanning]  [Meg Lanning]     [15]
# 1    [\n, [Stafanie Taylor], \n]           [WI]     [15]
# 2       [\n, [Alyssa Healy], \n]          [AUS]  [1,812]
# 3    [\n, [Smriti Mandhana], \n]          [IND]     [14]
# 4  [\n, [Amy Satterthwaite], \n]           [NZ]  [1,670]
# 5     [\n, [Tammy Beaumont], \n]          [ENG]     [19]
# 6    [\n, [Laura Wolvaardt], \n]           [SA]  [2,090]
# 7       [\n, [Ellyse Perry], \n]          [AUS]     [15]
# 8        [\n, [Mithali Raj], \n]          [IND]  [1,384]
# 9        [\n, [Lizelle Lee], \n]           [SA]     [12]

# %%
# top 10 ODI bowling womens cricket team

# %%
page2=requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/bowling")

# %%
Soup=BeautifulSoup(page1.content,'html.parser')

# %%
page2.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="Live Cricket Scores & News International Cricket Council"/>\n<meta property="og:image" content="https://www.icc-cricket.com/resources/ver/i/elements/defa
# ...

# %%
name=[]
team=[]
rating=[]

# %%
name_bowler1=Soup.find_all('div',class_="rankings-block__banner--name-large")
name_bowler1[0:10]
# Out:
# [<div class="rankings-block__banner--name-large">Meg Lanning</div>]

# %%
name_bowler2=Soup.find_all('td',class_="table-body__cell rankings-table__name name")
name_bowler2[0:10]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/545">Tammy Beaumont</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/3176">Laura Wolvaardt</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/471">Ellyse Perry</a>
#  </td>,
# ...

# %%
name_bowler=name_bowler1+name_bowler2
name_bowler
# Out:
# [<div class="rankings-block__banner--name-large">Meg Lanning</div>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/545">Tammy Beaumont</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/3176">Laura Wolvaardt</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
# ...

# %%
for i in name_bowler:
    name.append(i.get_text().replace('\n',''))
name[0:10]
# Out:
# [<div class="rankings-block__banner--name-large">Meg Lanning</div>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1809">Smriti Mandhana</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/545">Tammy Beaumont</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/3176">Laura Wolvaardt</a>
#  </td>,
#  <td class="table-body__cell rankings-table__name name">
# ...

# %%
team_bowler1=Soup.find_all('div',class_="rankings-block__banner--nationality")
team_bowler1[0:10]
# Out:
# [<div class="rankings-block__banner--nationality">
#  <div class="flag-15 AUS"></div>
#  <span class="rankings-block__banner--nation"></span>AUS</div>]

# %%
team_bowler2=Soup.find_all('span',class_="table-body__logo-text")
team_bowler2[0:10]
# Out:
# [<span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>]

# %%
team_bowler=team_bowler1+team_bowler2
team_bowler
# Out:
# [<div class="rankings-block__banner--nationality">
#  <div class="flag-15 AUS"></div>
#  <span class="rankings-block__banner--nation"></span>AUS</div>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SL</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">AUS</span>,
# ...

# %%
for i in team_bowler:
    team.append(i.get_text().replace('\n',''))
team[0:10]
# Out:
# [<div class="rankings-block__banner--name-large">Meg Lanning</div>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>]

# %%
score_rating1=Soup.find_all('div',class_="rankings-block__banner--rating")
rating1[0:10]
# Out:
# [<td class="rankings-block__banner--matches">15</td>]

# %%
scorer_ating2=Soup.find_all('td',class_="table-body__cell rating")
rating2[0:10]
# Out:
# [<td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>,
#  <td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">2,090</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,384</td>,
#  <td class="table-body__cell u-center-text">12</td>,
#  <td class="table-body__cell u-center-text">1,025</td>]

# %%
rating=rating1+rating2
rating
# Out:
# [<td class="rankings-block__banner--matches">15</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>,
#  <td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">2,090</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,384</td>,
#  <td class="table-body__cell u-center-text">12</td>,
#  <td class="table-body__cell u-center-text">1,025</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,101</td>,
#  <td class="table-body__cell u-center-text">5</td>,
#  <td class="table-body__cell u-center-text">306</td>,
#  <td class="table-body__cell u-center-text">11</td>,
#  <td class="table-body__cell u-center-text">519</td>,
# ...

# %%
for i in rating1:
    rating.append(i.get_text().replace('\n',''))
rating[0:10]
# Out:
# [<td class="rankings-block__banner--matches">15</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,812</td>,
#  <td class="table-body__cell u-center-text">14</td>,
#  <td class="table-body__cell u-center-text">1,670</td>,
#  <td class="table-body__cell u-center-text">19</td>,
#  <td class="table-body__cell u-center-text">2,090</td>,
#  <td class="table-body__cell u-center-text">15</td>,
#  <td class="table-body__cell u-center-text">1,384</td>,
#  <td class="table-body__cell u-center-text">12</td>]

# %%
NAME_BOWLER=[]
TEAM_BOWLER=[]
SCORE_RATING=[]

# %%
import pandas as pd
top10_batswomen=pd.DataFrame()
top10_batswomen['NAME_BOWLER']=name[0:10]
top10_batswomen['TEAM_BOWLER']=team[0:10]
top10_batswomen['SCORE_RATING']=rating[0:10]

# %%
top10_batswomen
# Out:
#                      NAME_BOWLER    TEAM_BOWLER SCORE_RATING
# 0                  [Meg Lanning]  [Meg Lanning]         [15]
# 1    [\n, [Stafanie Taylor], \n]           [WI]         [15]
# 2       [\n, [Alyssa Healy], \n]          [AUS]      [1,812]
# 3    [\n, [Smriti Mandhana], \n]          [IND]         [14]
# 4  [\n, [Amy Satterthwaite], \n]           [NZ]      [1,670]
# 5     [\n, [Tammy Beaumont], \n]          [ENG]         [19]
# 6    [\n, [Laura Wolvaardt], \n]           [SA]      [2,090]
# 7       [\n, [Ellyse Perry], \n]          [AUS]         [15]
# 8        [\n, [Mithali Raj], \n]          [IND]      [1,384]
# 9        [\n, [Lizelle Lee], \n]           [SA]         [12]
